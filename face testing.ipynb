# %%
from PIL import Image
from tensorflow.keras.applications.vgg16 import preprocess_input
import base64
from io import BytesIO
import json
import random
import cv2
from tensorflow.keras.models import load_model
import numpy as np

from tensorflow.keras.preprocessing import image
model = load_model('facefeatures_new_modelx2.h5')

face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

def face_extractor(img):
    #gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(img, 1.3, 5)
    
    if faces is ():
        return None

    for (x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,255),2)
        cropped_face = img[y:y+h, x:x+w]

    return cropped_face

video_capture = cv2.VideoCapture(0)
while True:
    _, frame = video_capture.read()
    #canvas = detect(gray, frame)
    #image, face =face_detector(frame)
    
    face=face_extractor(frame)
    if type(face) is np.ndarray:
        face = cv2.resize(face, (224, 224))
        im = Image.fromarray(face, 'RGB')
           #Resizing into 128x128 because we trained the model with this image size.
        img_array = np.array(im)
        img_array = np.expand_dims(img_array, axis=0)
        pred = model.predict(img_array)
        print(pred)
                     
        name="None matching"
        '''
        if(pred[0][0]>0.7):
            name='deepa'
        elif(pred[0][1]>0.7):
            name='bush'
        elif(pred[0][2]>0.7):
            name='numan'
        elif(pred[0][3]>0.7):
            name='sushma'
            '''
        if(pred[0][1]>0.5):
            name='numan'
        cv2.putText(frame,name, (50, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
    else:
        cv2.putText(frame,"No face found", (50, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
    cv2.imshow('Video', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
video_capture.release()
cv2.destroyAllWindows()
# Out:
# <>:20: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:20: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\Noman\AppData\Local\Temp/ipykernel_20316/882261748.py:20: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is ():
# [[1.9872374e-21 1.0000000e+00 0.0000000e+00]]
# [[6.980484e-24 1.000000e+00 0.000000e+00]]
# [[1.9553264e-26 1.0000000e+00 0.0000000e+00]]
# [[1.774388e-23 1.000000e+00 0.000000e+00]]
# [[1.1290939e-35 1.0000000e+00 0.0000000e+00]]
# [[1.0132712e-37 1.0000000e+00 0.0000000e+00]]
# [[0. 1. 0.]]
# [[1.1350511e-24 1.0000000e+00 0.0000000e+00]]
# [[7.2163954e-13 1.0000000e+00 0.0000000e+00]]
# [[0.3556315  0.64436847 0.        ]]
# [[8.747016e-15 1.000000e+00 0.000000e+00]]
# [[1.8830036e-33 1.0000000e+00 0.0000000e+00]]
# [[7.949494e-12 1.000000e+00 0.000000e+00]]
# [[6.0514446e-22 1.0000000e+00 0.0000000e+00]]
# [[1.747294e-13 1.000000e+00 0.000000e+00]]
# [[9.8877455e-11 1.0000000e+00 0.0000000e+00]]
# [[1.2980049e-06 9.9999869e-01 8.9393847e-37]]
# [[1.5233662e-09 1.0000000e+00 0.0000000e+00]]
# [[6.970941e-10 1.000000e+00 0.000000e+00]]
# [[1.1757887e-06 9.9999881e-01 0.0000000e+00]]
# [[5.497856e-13 1.000000e+00 0.000000e+00]]
# [[2.4166457e-07 9.9999976e-01 0.0000000e+00]]
# [[2.3933871e-06 9.9999762e-01 0.0000000e+00]]
# [[7.0786816e-09 1.0000000e+00 0.0000000e+00]]
# [[6.266118e-05 9.999373e-01 0.000000e+00]]
# [[2.741297e-10 1.000000e+00 0.000000e+00]]
# [[1.596576e-11 1.000000e+00 0.000000e+00]]
# [[2.1339891e-20 1.0000000e+00 0.0000000e+00]]
# [[2.0474039e-36 1.0000000e+00 0.0000000e+00]]
# [[3.3708452e-06 9.9999666e-01 0.0000000e+00]]
# [[0.00325493 0.9967451  0.        ]]
# [[1.0094971e-16 1.0000000e+00 0.0000000e+00]]
# [[5.248389e-22 1.000000e+00 0.000000e+00]]
# [[9.974162e-25 1.000000e+00 0.000000e+00]]
# [[1.002768e-18 1.000000e+00 0.000000e+00]]
# [[2.537829e-22 1.000000e+00 0.000000e+00]]
# [[1.3903013e-06 9.9999857e-01 5.0924415e-36]]
# [[2.528697e-37 1.000000e+00 0.000000e+00]]
# [[0. 1. 0.]]
# [[0. 1. 0.]]
# [[0. 1. 0.]]
# [[1.069311e-34 1.000000e+00 0.000000e+00]]
# [[2.4954629e-23 1.0000000e+00 0.0000000e+00]]
# [[0. 1. 0.]]
# [[2.4746009e-36 1.0000000e+00 0.0000000e+00]]
# [[5.4282016e-31 1.0000000e+00 0.0000000e+00]]
# [[5.2198947e-15 1.0000000e+00 0.0000000e+00]]

# %%
sudo pip install tensorflow
# Out:
#   File "<ipython-input-2-c350187f8051>", line 1
#     sudo pip install tensorflow
#          ^
# SyntaxError: invalid syntax

# %%
pip install tensorflow
# Out:
# Collecting tensorflow
#   Using cached tensorflow-2.6.0-cp38-cp38-win_amd64.whl (423.2 MB)
# Collecting google-pasta~=0.2
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Requirement already satisfied: grpcio<2.0,>=1.37.0 in c:\users\noman\anaconda3\lib\site-packages (from tensorflow) (1.40.0)
# Collecting termcolor~=1.1.0
#   Using cached termcolor-1.1.0-py3-none-any.whl
# Collecting h5py~=3.1.0
#   Using cached h5py-3.1.0-cp38-cp38-win_amd64.whl (2.7 MB)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\noman\anaconda3\lib\site-packages (from tensorflow) (1.12.1)
# Collecting tensorflow-estimator~=2.6
#   Using cached tensorflow_estimator-2.6.0-py2.py3-none-any.whl (462 kB)
# Requirement already satisfied: keras~=2.6 in c:\users\noman\anaconda3\lib\site-packages (from tensorflow) (2.6.0)
# Collecting gast==0.4.0
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: six~=1.15.0 in c:\users\noman\anaconda3\lib\site-packages (from tensorflow) (1.15.0)
# Collecting tensorboard~=2.6
#   Using cached tensorboard-2.6.0-py3-none-any.whl (5.6 MB)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\noman\anaconda3\lib\site-packages (from tensorflow) (3.18.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\noman\anaconda3\lib\site-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied: numpy~=1.19.2 in c:\users\noman\anaconda3\lib\site-packages (from tensorflow) (1.19.2)
# Collecting astunparse~=1.6.3
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: absl-py~=0.10 in c:\users\noman\anaconda3\lib\site-packages (from tensorflow) (0.14.0)
# Collecting flatbuffers~=1.12.0
#   Using cached flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting opt-einsum~=3.3.0
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting keras-preprocessing~=1.1.2
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting clang~=5.0
#   Using cached clang-5.0-py3-none-any.whl
# Requirement already satisfied: wheel~=0.35 in c:\users\noman\anaconda3\lib\site-packages (from tensorflow) (0.35.1)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\noman\anaconda3\lib\site-packages (from tensorboard~=2.6->tensorflow) (50.3.1.post20201107)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\noman\anaconda3\lib\site-packages (from tensorboard~=2.6->tensorflow) (1.35.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\noman\anaconda3\lib\site-packages (from tensorboard~=2.6->tensorflow) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\noman\anaconda3\lib\site-packages (from tensorboard~=2.6->tensorflow) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\noman\anaconda3\lib\site-packages (from tensorboard~=2.6->tensorflow) (1.8.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\noman\anaconda3\lib\site-packages (from tensorboard~=2.6->tensorflow) (3.3.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\noman\anaconda3\lib\site-packages (from tensorboard~=2.6->tensorflow) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\noman\anaconda3\lib\site-packages (from tensorboard~=2.6->tensorflow) (2.24.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\noman\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\noman\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\noman\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\noman\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\noman\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\noman\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\noman\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\noman\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\noman\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2020.6.20)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\noman\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (3.1.1)
# Installing collected packages: termcolor, tensorflow-estimator, tensorboard, opt-einsum, keras-preprocessing, h5py, google-pasta, gast, flatbuffers, clang, astunparse, tensorflow
#   Attempting uninstall: h5py
#     Found existing installation: h5py 2.10.0
#     Uninstalling h5py-2.10.0:
#       Successfully uninstalled h5py-2.10.0
# Successfully installed astunparse-1.6.3 clang-5.0 flatbuffers-1.12 gast-0.4.0 google-pasta-0.2.0 h5py-3.1.0 keras-preprocessing-1.1.2 opt-einsum-3.3.0 tensorboard-2.6.0 tensorflow-2.6.0 tensorflow-estimator-2.6.0 termcolor-1.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.5.3.56-cp38-cp38-win_amd64.whl (34.9 MB)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\noman\anaconda3\lib\site-packages (from opencv-python) (1.19.2)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.5.3.56
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install dlib
